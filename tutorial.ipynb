# %% [markdown]
# <a href="https://colab.research.google.com/github/Fadhila36/Learn-Yolo/blob/master/tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a align="left" href="https://ultralytics.com/yolov5" target="_blank">
# <img width="1024", src="https://user-images.githubusercontent.com/26833433/125273437-35b3fc00-e30d-11eb-9079-46f313325424.png"></a>
#
# This is the **official YOLOv5 🚀 notebook** by **Ultralytics**, and is freely available for redistribution under the [GPL-3.0 license](https://choosealicense.com/licenses/gpl-3.0/).
# For more information please visit https://github.com/ultralytics/yolov5 and https://ultralytics.com. Thank you!

# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
from yolov5 import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.0-177-g5402753 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 42.0/78.2 GB disk)

# %%
# !unzip -q ../train_data.zip -d ../

# %% [markdown]
# # 1. Inference
#
# `detect.py` runs YOLOv5 inference on a variety of sources, downloading models automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and saving results to `runs/detect`. Example inference sources are:
#
# ```shell
# python detect.py --source 0  # webcam
#                           img.jpg  # image
#                           vid.mp4  # video
#                           path/  # directory
#                           path/*.jpg  # glob
#                           'https://youtu.be/Zgi9g1ksQHc'  # YouTube
#                           'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream
# ```

# %%
# !python detect.py --weights runs/train/exp3/weights/best.pt --img 640 --conf 0.55 --source ../video.mp4
# Out:
# detect: weights=['runs/train/exp3/weights/best.pt'], source=../video.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.55, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-177-g5402753 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (2/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (3/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (4/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (5/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (6/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (7/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (8/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (9/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (10/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (11/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (12/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (13/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (14/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (15/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (16/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (17/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (18/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (19/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (20/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (21/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (22/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (23/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (24/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (25/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (26/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (27/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (28/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (29/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (30/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (31/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (32/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (33/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (34/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (35/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (36/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (37/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (38/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (39/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (40/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (41/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (42/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (43/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (44/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (45/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (46/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (47/582) /content/video.mp4: 384x640 1 Bola, Done. (0.028s)
# video 1/1 (48/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (49/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (50/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (51/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (52/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (53/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (54/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (55/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (56/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (57/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (58/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (59/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (60/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (61/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (62/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (63/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (64/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (65/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (66/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (67/582) /content/video.mp4: 384x640 1 Bola, Done. (0.028s)
# video 1/1 (68/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (69/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (70/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (71/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (72/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (73/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (74/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (75/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (76/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (77/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (78/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (79/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (80/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (81/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (82/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (83/582) /content/video.mp4: 384x640 1 Bola, Done. (0.028s)
# video 1/1 (84/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (85/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (86/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (87/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (88/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (89/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (90/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (91/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (92/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (93/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (94/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (95/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (96/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (97/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (98/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (99/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (100/582) /content/video.mp4: 384x640 1 Bola, Done. (0.028s)
# video 1/1 (101/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (102/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (103/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (104/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (105/582) /content/video.mp4: 384x640 Done. (0.028s)
# video 1/1 (106/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (107/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (108/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (109/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (110/582) /content/video.mp4: 384x640 Done. (0.028s)
# video 1/1 (111/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (112/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (113/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (114/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (115/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (116/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (117/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (118/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (119/582) /content/video.mp4: 384x640 Done. (0.028s)
# video 1/1 (120/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (121/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (122/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (123/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (124/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (125/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (126/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (127/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (128/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (129/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (130/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (131/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (132/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (133/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (134/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (135/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (136/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (137/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (138/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (139/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (140/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (141/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (142/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (143/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (144/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (145/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (146/582) /content/video.mp4: 384x640 Done. (0.028s)
# video 1/1 (147/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (148/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (149/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (150/582) /content/video.mp4: 384x640 1 Bola, Done. (0.028s)
# video 1/1 (151/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (152/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (153/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (154/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (155/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (156/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (157/582) /content/video.mp4: 384x640 Done. (0.028s)
# video 1/1 (158/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (159/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (160/582) /content/video.mp4: 384x640 Done. (0.029s)
# video 1/1 (161/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (162/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (163/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (164/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (165/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (166/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (167/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (168/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (169/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (170/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (171/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (172/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (173/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (174/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (175/582) /content/video.mp4: 384x640 1 Bola, Done. (0.028s)
# video 1/1 (176/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (177/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (178/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (179/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (180/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (181/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (182/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (183/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (184/582) /content/video.mp4: 384x640 Done. (0.030s)
# video 1/1 (185/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (186/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (187/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (188/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (189/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (190/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (191/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (192/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (193/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (194/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (195/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (196/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (197/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (198/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (199/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (200/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (201/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (202/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (203/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (204/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (205/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (206/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (207/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (208/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (209/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (210/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (211/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (212/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (213/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (214/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (215/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (216/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (217/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (218/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (219/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (220/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (221/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (222/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (223/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (224/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (225/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (226/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (227/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (228/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (229/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (230/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (231/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (232/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (233/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (234/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (235/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (236/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (237/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (238/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (239/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (240/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (241/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (242/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (243/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (244/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (245/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (246/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (247/582) /content/video.mp4: 384x640 Done. (0.028s)
# video 1/1 (248/582) /content/video.mp4: 384x640 Done. (0.028s)
# video 1/1 (249/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (250/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (251/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (252/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (253/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (254/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (255/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (256/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (257/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (258/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (259/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (260/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (261/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (262/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (263/582) /content/video.mp4: 384x640 Done. (0.028s)
# video 1/1 (264/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (265/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (266/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (267/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (268/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (269/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (270/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (271/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (272/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (273/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (274/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (275/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (276/582) /content/video.mp4: 384x640 Done. (0.028s)
# video 1/1 (277/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (278/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (279/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (280/582) /content/video.mp4: 384x640 Done. (0.026s)
# video 1/1 (281/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (282/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (283/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (284/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (285/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (286/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (287/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (288/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (289/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (290/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (291/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (292/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (293/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (294/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (295/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (296/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (297/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (298/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (299/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (300/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (301/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (302/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (303/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (304/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (305/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (306/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (307/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (308/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (309/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (310/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (311/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (312/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (313/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (314/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (315/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (316/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (317/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (318/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (319/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (320/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (321/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (322/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (323/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (324/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (325/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (326/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (327/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (328/582) /content/video.mp4: 384x640 Done. (0.028s)
# video 1/1 (329/582) /content/video.mp4: 384x640 Done. (0.028s)
# video 1/1 (330/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (331/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (332/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (333/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (334/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (335/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (336/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (337/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (338/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (339/582) /content/video.mp4: 384x640 Done. (0.028s)
# video 1/1 (340/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (341/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (342/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (343/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (344/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (345/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (346/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (347/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (348/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (349/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (350/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (351/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (352/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (353/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (354/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (355/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (356/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (357/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (358/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (359/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (360/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (361/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (362/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (363/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (364/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (365/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (366/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (367/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (368/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (369/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (370/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (371/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (372/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (373/582) /content/video.mp4: 384x640 Done. (0.028s)
# video 1/1 (374/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (375/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (376/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (377/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (378/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (379/582) /content/video.mp4: 384x640 Done. (0.028s)
# video 1/1 (380/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (381/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (382/582) /content/video.mp4: 384x640 Done. (0.028s)
# video 1/1 (383/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (384/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (385/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (386/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (387/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (388/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (389/582) /content/video.mp4: 384x640 Done. (0.028s)
# video 1/1 (390/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (391/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (392/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (393/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (394/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (395/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (396/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (397/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (398/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (399/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (400/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (401/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (402/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (403/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (404/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (405/582) /content/video.mp4: 384x640 Done. (0.030s)
# video 1/1 (406/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (407/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (408/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (409/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (410/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (411/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (412/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (413/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (414/582) /content/video.mp4: 384x640 Done. (0.028s)
# video 1/1 (415/582) /content/video.mp4: 384x640 Done. (0.028s)
# video 1/1 (416/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (417/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (418/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (419/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (420/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (421/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (422/582) /content/video.mp4: 384x640 Done. (0.028s)
# video 1/1 (423/582) /content/video.mp4: 384x640 Done. (0.028s)
# video 1/1 (424/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (425/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (426/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (427/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (428/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (429/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (430/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (431/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (432/582) /content/video.mp4: 384x640 Done. (0.028s)
# video 1/1 (433/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (434/582) /content/video.mp4: 384x640 Done. (0.028s)
# video 1/1 (435/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (436/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (437/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (438/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (439/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (440/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (441/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (442/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (443/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (444/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (445/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (446/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (447/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (448/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (449/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (450/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (451/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (452/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (453/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (454/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (455/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (456/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (457/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (458/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (459/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (460/582) /content/video.mp4: 384x640 Done. (0.028s)
# video 1/1 (461/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (462/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (463/582) /content/video.mp4: 384x640 Done. (0.028s)
# video 1/1 (464/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (465/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (466/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (467/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (468/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (469/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (470/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (471/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (472/582) /content/video.mp4: 384x640 Done. (0.028s)
# video 1/1 (473/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (474/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (475/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (476/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (477/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (478/582) /content/video.mp4: 384x640 Done. (0.028s)
# video 1/1 (479/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (480/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (481/582) /content/video.mp4: 384x640 Done. (0.028s)
# video 1/1 (482/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (483/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (484/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (485/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (486/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (487/582) /content/video.mp4: 384x640 Done. (0.028s)
# video 1/1 (488/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (489/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (490/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (491/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (492/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (493/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (494/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (495/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (496/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (497/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (498/582) /content/video.mp4: 384x640 Done. (0.028s)
# video 1/1 (499/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (500/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (501/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (502/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (503/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (504/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (505/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (506/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (507/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (508/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (509/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (510/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (511/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (512/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (513/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (514/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (515/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (516/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (517/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (518/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (519/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (520/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (521/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (522/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (523/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (524/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (525/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (526/582) /content/video.mp4: 384x640 1 Bola, Done. (0.028s)
# video 1/1 (527/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (528/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (529/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (530/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (531/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (532/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (533/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (534/582) /content/video.mp4: 384x640 Done. (0.032s)
# video 1/1 (535/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (536/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (537/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (538/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (539/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (540/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (541/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (542/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (543/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (544/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (545/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (546/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (547/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (548/582) /content/video.mp4: 384x640 1 Bola, Done. (0.031s)
# video 1/1 (549/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (550/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (551/582) /content/video.mp4: 384x640 1 Bola, Done. (0.037s)
# video 1/1 (552/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (553/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (554/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (555/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (556/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (557/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (558/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (559/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (560/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (561/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (562/582) /content/video.mp4: 384x640 1 Bola, Done. (0.027s)
# video 1/1 (563/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (564/582) /content/video.mp4: 384x640 Done. (0.028s)
# video 1/1 (565/582) /content/video.mp4: 384x640 Done. (0.028s)
# video 1/1 (566/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (567/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (568/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (569/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (570/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (571/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (572/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (573/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (574/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (575/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (576/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (577/582) /content/video.mp4: 384x640 Done. (0.028s)
# video 1/1 (578/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (579/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (580/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (581/582) /content/video.mp4: 384x640 Done. (0.027s)
# video 1/1 (582/582) /content/video.mp4: 384x640 Done. (0.027s)
# Speed: 0.7ms pre-process, 27.4ms inference, 0.8ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp4

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/127574988-6a558aa1-d268-44b9-bf6b-62d4c605cc72.jpg" width="600">

# %% [markdown]
# # 2. Validate
# Validate a model's accuracy on [COCO](https://cocodataset.org/#home) val or test-dev datasets. Models are downloaded automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases). To show results by class use the `--verbose` flag. Note that `pycocotools` metrics may be ~1% better than the equivalent repo metrics, as is visible below, due to slight differences in mAP computation.

# %% [markdown]
# ## COCO val
# Download [COCO val 2017](https://github.com/ultralytics/yolov5/blob/74b34872fdf41941cddcf243951cdb090fbac17b/data/coco.yaml#L14) dataset (1GB - 5000 images), and test model accuracy.

# %%
# Download COCO val
torch.hub.download_url_to_file('https://ultralytics.com/assets/coco2017val.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../datasets && rm tmp.zip
# Out:
#   0%|          | 0.00/780M [00:00<?, ?B/s]

# %%
# Run YOLOv5x on COCO val
# !python val.py --weights yolov5x.pt --data coco.yaml --img 640 --iou 0.65 --half
# Out:
# val: data=/content/yolov5/data/coco.yaml, weights=['yolov5x.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.65, task=val, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=True, project=runs/val, name=exp, exist_ok=False, half=True
# YOLOv5 🚀 v6.0-48-g84a8099 torch 1.10.0+cu102 CUDA:0 (Tesla V100-SXM2-16GB, 16160MiB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v6.0/yolov5x.pt to yolov5x.pt...
# 100% 166M/166M [00:03<00:00, 54.1MB/s]
#
# Fusing layers...
# Model Summary: 444 layers, 86705005 parameters, 0 gradients
# val: Scanning '../datasets/coco/val2017' images and labels...4952 found, 48 missing, 0 empty, 0 corrupted: 100% 5000/5000 [00:01<00:00, 2636.64it/s]
# val: New cache created: ../datasets/coco/val2017.cache
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 157/157 [01:12<00:00,  2.17it/s]
#                  all       5000      36335      0.729       0.63      0.683      0.496
# Speed: 0.1ms pre-process, 4.9ms inference, 1.9ms NMS per image at shape (32, 3, 640, 640)
#
# Evaluating pycocotools mAP... saving runs/val/exp/yolov5x_predictions.json...
# loading annotations into memory...
# Done (t=0.46s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=5.15s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=90.39s).
# Accumulating evaluation results...
# DONE (t=14.54s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.507
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.689
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.552
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.345
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.559
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.652
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.381
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.630
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.682
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.526
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.732
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.829
# Results saved to runs/val/exp

# %% [markdown]
# ## COCO test
# Download [COCO test2017](https://github.com/ultralytics/yolov5/blob/74b34872fdf41941cddcf243951cdb090fbac17b/data/coco.yaml#L15) dataset (7GB - 40,000 images), to test model accuracy on test-dev set (**20,000 images, no labels**). Results are saved to a `*.json` file which should be **zipped** and submitted to the evaluation server at https://competitions.codalab.org/competitions/20794.

# %%
# Download COCO test-dev2017
torch.hub.download_url_to_file('https://ultralytics.com/assets/coco2017labels.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../datasets && rm tmp.zip
# !f="test2017.zip" && curl http://images.cocodataset.org/zips/$f -o $f && unzip -q $f -d ../datasets/coco/images

# %%
# Run YOLOv5x on COCO test
# !python val.py --weights yolov5x.pt --data coco.yaml --img 640 --iou 0.65 --half --task test

# %% [markdown]
# # 3. Train
#
# <p align=""><a href="https://roboflow.com/?ref=ultralytics"><img width="1000" src="https://uploads-ssl.webflow.com/5f6bc60e665f54545a1e52a5/615627e5824c9c6195abfda9_computer-vision-cycle.png"/></a></p>
# Close the active learning loop by sampling images from your inference conditions with the `roboflow` pip package
# <br><br>
#
# Train a YOLOv5s model on the [COCO128](https://www.kaggle.com/ultralytics/coco128) dataset with `--data coco128.yaml`, starting from pretrained `--weights yolov5s.pt`, or from randomly initialized `--weights '' --cfg yolov5s.yaml`.
#
# - **Pretrained [Models](https://github.com/ultralytics/yolov5/tree/master/models)** are downloaded
# automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases)
# - **[Datasets](https://github.com/ultralytics/yolov5/tree/master/data)** available for autodownload include: [COCO](https://github.com/ultralytics/yolov5/blob/master/data/coco.yaml), [COCO128](https://github.com/ultralytics/yolov5/blob/master/data/coco128.yaml), [VOC](https://github.com/ultralytics/yolov5/blob/master/data/VOC.yaml), [Argoverse](https://github.com/ultralytics/yolov5/blob/master/data/Argoverse.yaml), [VisDrone](https://github.com/ultralytics/yolov5/blob/master/data/VisDrone.yaml), [GlobalWheat](https://github.com/ultralytics/yolov5/blob/master/data/GlobalWheat2020.yaml), [xView](https://github.com/ultralytics/yolov5/blob/master/data/xView.yaml), [Objects365](https://github.com/ultralytics/yolov5/blob/master/data/Objects365.yaml), [SKU-110K](https://github.com/ultralytics/yolov5/blob/master/data/SKU-110K.yaml).
# - **Training Results** are saved to `runs/train/` with incrementing run directories, i.e. `runs/train/exp2`, `runs/train/exp3` etc.
# <br><br>
#
# ## Train on Custom Data with Roboflow 🌟 NEW
#
# [Roboflow](https://roboflow.com/?ref=ultralytics) enables you to easily **organize, label, and prepare** a high quality dataset with your own custom data. Roboflow also makes it easy to establish an active learning pipeline, collaborate with your team on dataset improvement, and integrate directly into your model building workflow with the `roboflow` pip package.
#
# - Custom Training Example: [https://blog.roboflow.com/how-to-train-yolov5-on-a-custom-dataset/](https://blog.roboflow.com/how-to-train-yolov5-on-a-custom-dataset/?ref=ultralytics)
# - Custom Training Notebook: [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/roboflow-ai/yolov5-custom-training-tutorial/blob/main/yolov5-custom-training.ipynb)
# <br>
#
# <p align=""><a href="https://roboflow.com/?ref=ultralytics"><img width="480" src="https://uploads-ssl.webflow.com/5f6bc60e665f54545a1e52a5/6152a275ad4b4ac20cd2e21a_roboflow-annotate.gif"/></a></p>Label images lightning fast (including with model-assisted labeling)

# %%
# Tensorboard  (optional)
# %load_ext tensorboard
# %tensorboard --logdir runs/train

# %%
# Weights & Biases  (optional)
# %pip install -q wandb
import wandb
wandb.login()

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 2 --epochs 120 --data custom_data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=120, batch_size=2, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-177-g5402753 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# hyperparameters: lr0=0.01, lrf=0.1, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 🚀 runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model Summary: 270 layers, 7022326 parameters, 7022326 gradients, 15.8 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# Scaled weight_decay = 0.0005
# optimizer: SGD with parameter groups 57 weight, 60 weight (no decay), 60 bias
# albumentations: version 1.0.3 required by YOLOv5, but version 0.1.12 is currently installed
# train: Scanning '../train_data/labels/train.cache' images and labels... 36 found, 0 missing, 0 empty, 0 corrupted: 100% 36/36 [00:00<?, ?it/s]
# train: Caching images (0.0GB ram): 100% 36/36 [00:07<00:00,  4.51it/s]
# val: Scanning '../train_data/labels/val.cache' images and labels... 20 found, 0 missing, 0 empty, 0 corrupted: 100% 20/20 [00:00<?, ?it/s]
# val: Caching images (0.0GB ram): 100% 20/20 [00:05<00:00,  3.38it/s]
# Plotting labels to runs/train/exp4/labels.jpg...
#
# AutoAnchor: 4.84 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp4
# Starting training for 120 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      0/119     0.51G    0.1112   0.03278         0         8       640: 100% 18/18 [00:08<00:00,  2.20it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:00<00:00,  6.48it/s]
#                  all         20         20     0.0142      0.189    0.00461   0.000712
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      1/119    0.688G       0.1   0.03258         0        10       640: 100% 18/18 [00:05<00:00,  3.31it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:00<00:00,  6.49it/s]
#                  all         20         20    0.00667        0.2    0.00241   0.000498
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      2/119    0.688G    0.1058   0.03113         0         4       640: 100% 18/18 [00:05<00:00,  3.33it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:00<00:00,  6.69it/s]
#                  all         20         20    0.00421        0.1    0.00197   0.000348
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      3/119    0.688G   0.09537   0.03231         0         7       640: 100% 18/18 [00:05<00:00,  3.39it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:00<00:00,  6.78it/s]
#                  all         20         20    0.00636        0.2    0.00256   0.000517
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      4/119    0.688G   0.08966   0.03385         0         3       640: 100% 18/18 [00:05<00:00,  3.38it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:00<00:00,  6.75it/s]
#                  all         20         20     0.0739       0.05    0.00896    0.00209
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      5/119    0.688G   0.09397   0.03188         0         3       640: 100% 18/18 [00:05<00:00,  3.35it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:00<00:00,  7.08it/s]
#                  all         20         20     0.0701        0.1     0.0157    0.00408
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      6/119    0.688G   0.08434   0.03451         0         3       640: 100% 18/18 [00:05<00:00,  3.41it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:00<00:00,  7.24it/s]
#                  all         20         20     0.0652       0.15      0.023    0.00499
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      7/119    0.688G   0.08491   0.03471         0         2       640: 100% 18/18 [00:05<00:00,  3.44it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:00<00:00,  7.75it/s]
#                  all         20         20     0.0603       0.25     0.0332    0.00795
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      8/119    0.688G   0.07871   0.03297         0         4       640: 100% 18/18 [00:05<00:00,  3.43it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:00<00:00,  7.86it/s]
#                  all         20         20      0.121       0.25     0.0536     0.0169
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      9/119    0.688G   0.07942   0.03109         0         3       640: 100% 18/18 [00:05<00:00,  3.43it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:00<00:00,  8.00it/s]
#                  all         20         20      0.271        0.3       0.14     0.0353
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     10/119    0.688G   0.08329   0.03123         0         7       640:  50% 9/18 [00:02<00:02,  3.47it/s]

# %% [markdown]
# # 4. Visualize

# %% [markdown]
# ## Weights & Biases Logging 🌟 NEW
#
# [Weights & Biases](https://wandb.ai/site?utm_campaign=repo_yolo_notebook) (W&B) is now integrated with YOLOv5 for real-time visualization and cloud logging of training runs. This allows for better run comparison and introspection, as well improved visibility and collaboration for teams. To enable W&B `pip install wandb`, and then train normally (you will be guided through setup on first use).
#
# During training you will see live updates at [https://wandb.ai/home](https://wandb.ai/home?utm_campaign=repo_yolo_notebook), and you can create and share detailed [Reports](https://wandb.ai/glenn-jocher/yolov5_tutorial/reports/YOLOv5-COCO128-Tutorial-Results--VmlldzozMDI5OTY) of your results. For more information see the [YOLOv5 Weights & Biases Tutorial](https://github.com/ultralytics/yolov5/issues/1289).
#
# <p align="left"><img width="900" alt="Weights & Biases dashboard" src="https://user-images.githubusercontent.com/26833433/135390767-c28b050f-8455-4004-adb0-3b730386e2b2.png"></p>

# %% [markdown]
# ## Local Logging
#
# All results are logged by default to `runs/train`, with a new experiment directory created for each new training as `runs/train/exp2`, `runs/train/exp3`, etc. View train and val jpgs to see mosaics, labels, predictions and augmentation effects. Note an Ultralytics **Mosaic Dataloader** is used for training (shown below), which combines 4 images into 1 mosaic during training.
#
# > <img src="https://user-images.githubusercontent.com/26833433/131255960-b536647f-7c61-4f60-bbc5-cb2544d71b2a.jpg" width="700">
# `train_batch0.jpg` shows train batch 0 mosaics and labels
#
# > <img src="https://user-images.githubusercontent.com/26833433/131256748-603cafc7-55d1-4e58-ab26-83657761aed9.jpg" width="700">
# `test_batch0_labels.jpg` shows val batch 0 labels
#
# > <img src="https://user-images.githubusercontent.com/26833433/131256752-3f25d7a5-7b0f-4bb3-ab78-46343c3800fe.jpg" width="700">
# `test_batch0_pred.jpg` shows val batch 0 _predictions_
#
# Training results are automatically logged to [Tensorboard](https://www.tensorflow.org/tensorboard) and [CSV](https://github.com/ultralytics/yolov5/pull/4148) as `results.csv`, which is plotted as `results.png` (below) after training completes. You can also plot any `results.csv` file manually:
#
# ```python
# from utils.plots import plot_results
# plot_results('path/to/results.csv')  # plot 'results.csv' as 'results.png'
# ```
#
# <img align="left" width="800" alt="COCO128 Training Results" src="https://user-images.githubusercontent.com/26833433/126906780-8c5e2990-6116-4de6-b78a-367244a33ccf.png">

# %% [markdown]
# # Environments
#
# YOLOv5 may be run in any of the following up-to-date verified environments (with all dependencies including [CUDA](https://developer.nvidia.com/cuda)/[CUDNN](https://developer.nvidia.com/cudnn), [Python](https://www.python.org/) and [PyTorch](https://pytorch.org/) preinstalled):
#
# - **Google Colab and Kaggle** notebooks with free GPU: <a href="https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a> <a href="https://www.kaggle.com/ultralytics/yolov5"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
# - **Google Cloud** Deep Learning VM. See [GCP Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/GCP-Quickstart)
# - **Amazon** Deep Learning AMI. See [AWS Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/AWS-Quickstart)
# - **Docker Image**. See [Docker Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/Docker-Quickstart) <a href="https://hub.docker.com/r/ultralytics/yolov5"><img src="https://img.shields.io/docker/pulls/ultralytics/yolov5?logo=docker" alt="Docker Pulls"></a>

# %% [markdown]
# # Status
#
# ![CI CPU testing](https://github.com/ultralytics/yolov5/workflows/CI%20CPU%20testing/badge.svg)
#
# If this badge is green, all [YOLOv5 GitHub Actions](https://github.com/ultralytics/yolov5/actions) Continuous Integration (CI) tests are currently passing. CI tests verify correct operation of YOLOv5 training ([train.py](https://github.com/ultralytics/yolov5/blob/master/train.py)), testing ([val.py](https://github.com/ultralytics/yolov5/blob/master/val.py)), inference ([detect.py](https://github.com/ultralytics/yolov5/blob/master/detect.py)) and export ([export.py](https://github.com/ultralytics/yolov5/blob/master/export.py)) on MacOS, Windows, and Ubuntu every 24 hours and on every commit.

# %% [markdown]
# # Appendix
#
# Optional extras below. Unit tests validate repo functionality and should be run on any PRs submitted.

# %%
# Reproduce
for x in 'yolov5s', 'yolov5m', 'yolov5l', 'yolov5x':
  # !python val.py --weights {x}.pt --data coco.yaml --img 640 --task speed  # speed
  # !python val.py --weights {x}.pt --data coco.yaml --img 640 --conf 0.001 --iou 0.65  # mAP

# %%
# PyTorch Hub
import torch

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# Images
dir = 'https://ultralytics.com/images/'
imgs = [dir + f for f in ('zidane.jpg', 'bus.jpg')]  # batch of images

# Inference
results = model(imgs)
results.print()  # or .show(), .save()

# %%
# CI Checks
# %%shell
export PYTHONPATH="$PWD"  # to run *.py. files in subdirectories
rm -rf runs  # remove runs/
for m in yolov5n; do  # models
  python train.py --img 64 --batch 32 --weights $m.pt --epochs 1 --device 0  # train pretrained
  python train.py --img 64 --batch 32 --weights '' --cfg $m.yaml --epochs 1 --device 0  # train scratch
  for d in 0 cpu; do  # devices
    python val.py --weights $m.pt --device $d # val official
    python val.py --weights runs/train/exp/weights/best.pt --device $d # val custom
    python detect.py --weights $m.pt --device $d  # detect official
    python detect.py --weights runs/train/exp/weights/best.pt --device $d  # detect custom
  done
  python hubconf.py  # hub
  python models/yolo.py --cfg $m.yaml  # build PyTorch model
  python models/tf.py --weights $m.pt  # build TensorFlow model
  python export.py --img 64 --batch 1 --weights $m.pt --include torchscript onnx  # export
done

# %%
# Profile
from utils.torch_utils import profile

m1 = lambda x: x * torch.sigmoid(x)
m2 = torch.nn.SiLU()
results = profile(input=torch.randn(16, 3, 640, 640), ops=[m1, m2], n=100)

# %%
# Evolve
# !python train.py --img 640 --batch 64 --epochs 100 --data coco128.yaml --weights yolov5s.pt --cache --noautoanchor --evolve
# !d=runs/train/evolve && cp evolve.* $d && zip -r evolve.zip $d && gsutil mv evolve.zip gs://bucket  # upload results (optional)

# %%
# VOC
for b, m in zip([64, 48, 32, 16], ['yolov5s', 'yolov5m', 'yolov5l', 'yolov5x']):  # zip(batch_size, model)
  # !python train.py --batch {b} --weights {m}.pt --data VOC.yaml --epochs 50 --cache --img 512 --nosave --hyp hyp.finetune.yaml --project VOC --name {m}

# %%
# TensorRT 
# https://developer.nvidia.com/nvidia-tensorrt-download
# !lsb_release -a  # check system
# %ls /usr/local | grep cuda  # check CUDA
# !wget https://ultralytics.com/assets/TensorRT-8.2.0.6.Linux.x86_64-gnu.cuda-11.4.cudnn8.2.tar.gz  # download
![ -d /content/TensorRT-8.2.0.6/ ] || tar -C /content/ -zxf ./TensorRT-8.2.0.6.Linux.x86_64-gnu.cuda-11.4.cudnn8.2.tar.gz  # unzip
# %pip list | grep tensorrt || pip install /content/TensorRT-8.2.0.6/python/tensorrt-8.2.0.6-cp37-none-linux_x86_64.whl  # install
# %env LD_LIBRARY_PATH=/usr/local/cuda-11.1/lib64:/content/cuda-11.1/lib64:/content/TensorRT-8.2.0.6/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64  # add to path

# !python export.py --weights yolov5s.pt --include engine --imgsz 640 640 --device 0
# !python detect.py --weights yolov5s.engine --imgsz 640 640 --device 0
